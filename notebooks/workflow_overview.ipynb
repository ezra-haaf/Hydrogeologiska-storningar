# %% [markdown]
# # Workflow Overview
#
# A second notebook that shows how a topic can appear in another gallery section.

# %% [markdown]
# ## Suggested next steps
#
# Use this notebook pattern for walkthroughs, validation flows, or small method demos.

# %%
from IPython.display import display

svg = """
<svg xmlns="http://www.w3.org/2000/svg" width="360" height="220" viewBox="0 0 360 220">
  <rect width="360" height="220" rx="18" fill="#fff7ed"/>
  <rect x="24" y="28" width="170" height="18" rx="9" fill="#ea580c" opacity="0.9"/>
  <path d="M36 170 C88 120, 118 150, 164 112 S250 72, 320 126" fill="none" stroke="#c2410c" stroke-width="8" stroke-linecap="round"/>
  <circle cx="86" cy="136" r="9" fill="#fdba74"/>
  <circle cx="164" cy="112" r="9" fill="#fb923c"/>
  <circle cx="238" cy="92" r="9" fill="#f97316"/>
  <circle cx="320" cy="126" r="9" fill="#ea580c"/>
  <rect x="24" y="182" width="108" height="10" rx="5" fill="#9a3412" opacity="0.35"/>
  <text x="24" y="205" font-family="Segoe UI, Arial, sans-serif" font-size="18" fill="#7c2d12">Workflow preview</text>
</svg>
"""

display({"image/svg+xml": svg}, raw=True)
