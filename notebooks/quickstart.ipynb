# %% [markdown]
# # Quickstart Example
#
# A small starter notebook used to demonstrate the gallery boilerplate.

# %% [markdown]
# ## Notes
#
# - A notebook stored outside the Sphinx source tree
# - A pre-rendered visual output that can be reused as a gallery thumbnail
# - A minimal structure that can be copied for new examples

# %%
from IPython.display import display

svg = """
<svg xmlns="http://www.w3.org/2000/svg" width="360" height="220" viewBox="0 0 360 220">
  <rect width="360" height="220" rx="18" fill="#f8fafc"/>
  <rect x="24" y="28" width="140" height="18" rx="9" fill="#0f766e" opacity="0.9"/>
  <rect x="24" y="62" width="220" height="12" rx="6" fill="#94a3b8" opacity="0.55"/>
  <rect x="24" y="84" width="180" height="12" rx="6" fill="#94a3b8" opacity="0.4"/>
  <rect x="24" y="126" width="312" height="58" rx="14" fill="#ccfbf1"/>
  <circle cx="70" cy="155" r="20" fill="#14b8a6"/>
  <circle cx="145" cy="155" r="20" fill="#0f766e" opacity="0.85"/>
  <circle cx="220" cy="155" r="20" fill="#134e4a" opacity="0.75"/>
  <text x="24" y="205" font-family="Segoe UI, Arial, sans-serif" font-size="18" fill="#134e4a">Quickstart preview</text>
</svg>
"""

display({"image/svg+xml": svg}, raw=True)
